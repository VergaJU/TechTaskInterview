# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
logs = pd.read_csv('../logs/classifier_training_logs.csv', index_col=0)

# %%
sns.lineplot(logs)
# Out:
# <Axes: xlabel='epoch'>

# %%
with open('../logs/classifier_metrics.pkl','rb')as f:
    metrics=pickle.load(f)

labels=['Basal-G3', 'Her2-G2', 'Her2-G3', 'LumA-G2', 'LumB-G3', 'Normal-G2']

# %%
print(metrics['classification_report'])
# Out:
#               precision    recall  f1-score   support
#
#     Basal-G3       0.98      0.98      0.98        45
#      Her2-G2       0.89      0.89      0.89         9
#      Her2-G3       0.87      0.82      0.84        72
#      LumA-G2       0.87      0.88      0.87       177
#      LumB-G3       0.80      0.83      0.82        78
#    Normal-G2       0.85      0.85      0.85       110
#
#     accuracy                           0.87       491
#    macro avg       0.88      0.87      0.88       491
# weighted avg       0.87      0.87      0.87       491

# %%
cm=pd.DataFrame(metrics['confusion_matrix'], index=labels, columns=labels)

# %%
plt.figure()
sns.heatmap(cm, annot=True, fmt='n')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()
